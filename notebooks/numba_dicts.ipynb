# %% [markdown]
# # Numba Typed Dictionaries
#
# Examples of using Numba's typed dictionaries with JIT-compiled functions.

# %%
import numpy as np
import re
from numba import njit, types
from numba.typed import Dict
import time

# Import loader for real data experiments
from specparser.amt import loader

# %% [markdown]
# ## 1. Basic Typed Dict
#
# Create and populate a typed dictionary outside JIT.

# %%
# Create a typed dict with int64 keys and float64 values
d = Dict.empty(
    key_type=types.int64,
    value_type=types.float64,
)

# Populate it
d[1] = 1.5
d[2] = 2.5
d[3] = 3.5

print(f"Dict: {dict(d)}")
print(f"d[2] = {d[2]}")
print(f"len(d) = {len(d)}")
# Out:
# Dict: {1: 1.5, 2: 2.5, 3: 3.5}
# d[2] = 2.5
# len(d) = 3

# %% [markdown]
# ## 2. JIT Function with Dict Input
#
# Pass a typed dict to a JIT-compiled function.

# %%
@njit
def sum_dict_values(d):
    """Sum all values in a typed dict."""
    total = 0.0
    for k in d:
        total += d[k]
    return total

@njit
def lookup_with_default(d, key, default):
    """Lookup with default value if key not found."""
    if key in d:
        return d[key]
    return default

# Test
print(f"Sum of values: {sum_dict_values(d)}")
print(f"d[2] = {lookup_with_default(d, 2, -1.0)}")
print(f"d[99] = {lookup_with_default(d, 99, -1.0)}")
# Out:
# Sum of values: 7.5
# d[2] = 2.5
# d[99] = -1.0

# %% [markdown]
# ## 3. JIT Function that Creates Dict
#
# Build a typed dict inside a JIT-compiled function.

# %%
@njit
def create_squares_dict(n):
    """Create a dict mapping i -> i^2 for i in range(n)."""
    d = Dict.empty(
        key_type=types.int64,
        value_type=types.int64,
    )
    for i in range(n):
        d[i] = i * i
    return d

squares = create_squares_dict(10)
print(f"Squares: {dict(squares)}")
# Out:
# Squares: {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# ## 4. Dict with String Keys
#
# Using unicode strings as keys (requires `types.unicode_type`).

# %%
# Create dict with string keys
str_dict = Dict.empty(
    key_type=types.unicode_type,
    value_type=types.float64,
)

str_dict["apple"] = 1.0
str_dict["banana"] = 2.0
str_dict["cherry"] = 3.0

print(f"str_dict['banana'] = {str_dict['banana']}")
# Out:
# str_dict['banana'] = 2.0

# %%
@njit
def lookup_string_key(d, key):
    """Lookup a string key in a typed dict."""
    if key in d:
        return d[key]
    return -1.0

print(f"lookup('apple') = {lookup_string_key(str_dict, 'apple')}")
print(f"lookup('missing') = {lookup_string_key(str_dict, 'missing')}")
# Out:
# lookup('apple') = 1.0
# lookup('missing') = -1.0

# %% [markdown]
# ## 5. Performance Comparison
#
# Compare lookup speed: Numba typed dict vs Python dict.

# %%
# Create large dicts
N = 100_000

# Python dict
py_dict = {i: float(i) for i in range(N)}

# Numba typed dict
nb_dict = Dict.empty(key_type=types.int64, value_type=types.float64)
for i in range(N):
    nb_dict[i] = float(i)

# Keys to lookup
keys = np.random.randint(0, N, size=1_000_000)

# %%
@njit
def numba_lookups(d, keys):
    """Perform many lookups in a typed dict."""
    total = 0.0
    for k in keys:
        total += d[k]
    return total

def python_lookups(d, keys):
    """Perform many lookups in a Python dict."""
    total = 0.0
    for k in keys:
        total += d[k]
    return total

# Warmup
_ = numba_lookups(nb_dict, keys[:100])

# %%
# Benchmark Python dict
t0 = time.perf_counter()
py_result = python_lookups(py_dict, keys)
py_time = time.perf_counter() - t0
print(f"Python dict: {py_time:.3f}s")

# Benchmark Numba typed dict
t0 = time.perf_counter()
nb_result = numba_lookups(nb_dict, keys)
nb_time = time.perf_counter() - t0
print(f"Numba dict:  {nb_time:.3f}s")

print(f"\nSpeedup: {py_time / nb_time:.1f}x")
print(f"Results match: {abs(py_result - nb_result) < 1e-6}")
# Out:
# Python dict: 0.091s
# Numba dict:  0.009s
#
# Speedup: 10.6x
# Results match: True

# %% [markdown]
# ## 6. Real Data: Asset Lookup Dict
#
# Use the loader module to build a lookup dict from AMT data.

# %%
# Load AMT data
amt_path = "../data/amt.yml"
amt_data = loader.load_amt(amt_path)

# Get all assets
assets_table = loader.assets(amt_path, live_only=True)
print(f"Found {len(assets_table['rows'])} live assets")
# Out:
# Found 189 live assets

# %%
# Build a string -> int index lookup
asset_to_idx = Dict.empty(
    key_type=types.unicode_type,
    value_type=types.int64,
)

for i, row in enumerate(assets_table['rows']):
    asset_name = row[0]
    asset_to_idx[asset_name] = i

print(f"Built lookup for {len(asset_to_idx)} assets")
print(f"First 5: {list(asset_to_idx.keys())[:5]}")
# Out:
# Built lookup for 189 assets
# First 5: ['LA Comdty', 'LP Comdty', 'LX Comdty', 'LA Comdty TKRZ', 'LP Comdty TKRZ']

# %%
@njit
def get_asset_index(lookup, name):
    """Get asset index from lookup dict."""
    if name in lookup:
        return lookup[name]
    return -1

# Test with a known asset
test_asset = list(asset_to_idx.keys())[0]
print(f"Index of '{test_asset}': {get_asset_index(asset_to_idx, test_asset)}")
print(f"Index of 'UNKNOWN': {get_asset_index(asset_to_idx, 'UNKNOWN')}")
# Out:
# Index of 'LA Comdty': 0
# Index of 'UNKNOWN': -1

# %% [markdown]
# ## 7. Nested Data: Dict of Arrays
#
# Store numpy arrays as dict values (requires specific array type).

# %%
from numba.core import types as nb_types

# Dict mapping int -> 1D float64 array
array_dict = Dict.empty(
    key_type=types.int64,
    value_type=types.float64[:],  # 1D array type
)

# Populate with arrays of different sizes
array_dict[0] = np.array([1.0, 2.0, 3.0])
array_dict[1] = np.array([10.0, 20.0])
array_dict[2] = np.array([100.0])

print(f"array_dict[0] = {array_dict[0]}")
print(f"array_dict[1] = {array_dict[1]}")
# Out:
# array_dict[0] = [1. 2. 3.]
# array_dict[1] = [10. 20.]

# %%
@njit
def sum_array_at_key(d, key):
    """Sum the array stored at a given key."""
    if key in d:
        arr = d[key]
        total = 0.0
        for i in range(len(arr)):
            total += arr[i]
        return total
    return 0.0

print(f"Sum at key 0: {sum_array_at_key(array_dict, 0)}")
print(f"Sum at key 1: {sum_array_at_key(array_dict, 1)}")
print(f"Sum at key 99: {sum_array_at_key(array_dict, 99)}")
# Out:
# Sum at key 0: 6.0
# Sum at key 1: 30.0
# Sum at key 99: 0.0

# %% [markdown]
# ## 8. Tuple Keys
#
# Using tuples as dictionary keys.

# %%
from numba import types

# Dict with (int64, int64) tuple keys
tuple_key_type = types.UniTuple(types.int64, 2)

coord_dict = Dict.empty(
    key_type=tuple_key_type,
    value_type=types.float64,
)

# Populate
coord_dict[(0, 0)] = 1.0
coord_dict[(1, 0)] = 2.0
coord_dict[(0, 1)] = 3.0
coord_dict[(1, 1)] = 4.0

print(f"coord_dict[(1, 1)] = {coord_dict[(1, 1)]}")
# Out:
# coord_dict[(1, 1)] = 4.0

# %%
@njit
def sparse_matrix_lookup(d, row, col, default):
    """Lookup (row, col) in sparse matrix dict."""
    key = (row, col)
    if key in d:
        return d[key]
    return default

print(f"(1, 1) = {sparse_matrix_lookup(coord_dict, 1, 1, 0.0)}")
print(f"(2, 2) = {sparse_matrix_lookup(coord_dict, 2, 2, 0.0)}")
# Out:
# (1, 1) = 4.0
# (2, 2) = 0.0

# %% [markdown]
# ## 9. Asset & Schedule Data Structures
#
# Two separate data structures for asset data:
# 1. **asset_data_nb**: Numba `Dict[str, str]` - flattened asset fields with dot-paths
# 2. **schedule_data**: Python dict of numpy StringDType arrays - columnar schedule data

# %%
def flatten_dict(d, prefix=""):
    """
    Flatten a nested dict to dot-separated keys, all values as strings.
    
    Examples:
        {"a": 1, "b": {"c": 2}} -> {"a": "1", "b.c": "2"}
        {"x": [10, 20, 30]} -> {"x.0": "10", "x.1": "20", "x.2": "30"}
    """
    result = {}
    for key, value in d.items():
        full_key = f"{prefix}.{key}" if prefix else str(key)
        
        if isinstance(value, dict):
            # Recurse into nested dict
            result.update(flatten_dict(value, full_key))
        elif isinstance(value, (list, tuple)):
            # Expand list/tuple with numeric indices
            for i, item in enumerate(value):
                item_key = f"{full_key}.{i}"
                if isinstance(item, dict):
                    result.update(flatten_dict(item, item_key))
                else:
                    result[item_key] = str(item)
        else:
            # Convert scalar to string
            result[full_key] = str(value)
    return result


def dict_to_numba(py_dict):
    """Convert a Python dict to a Numba typed dict (string -> string)."""
    nb_dict = Dict.empty(
        key_type=types.unicode_type,
        value_type=types.unicode_type,
    )
    for k, v in py_dict.items():
        nb_dict[k] = v
    return nb_dict

# %%
# Get asset data for a specific asset
test_asset = list(asset_to_idx.keys())[0]
asset_data = loader.get_asset(amt_path, test_asset)

# Get schedule directly from AMT data (inline, no schedules module)
schedule_name = asset_data.get("Options")
expiry_schedules = amt_data.get("expiry_schedules", {})
raw_schedule = expiry_schedules.get(schedule_name, []) if schedule_name else []

def split_code_value(s):
    """Split 'F-3' into ('F', '-3'), 'R' into ('R', '')"""
    m = re.match(r"^([A-Z]+)(.*)$", s)
    return (m.group(1), m.group(2)) if m else (s, "")

# Parse schedule into columnar format
schcnt_list, schid_list, asset_list = [], [], []
ntrc_list, ntrv_list = [], []
xprc_list, xprv_list = [], []
wgt_list = []

for i, entry in enumerate(raw_schedule):
    parts = entry.split("_")
    entry_part = parts[0] if len(parts) > 0 else ""
    expiry_part = parts[1] if len(parts) > 1 else ""
    wgt = parts[2] if len(parts) > 2 else ""
    
    ntrc, ntrv = split_code_value(entry_part)
    xprc, xprv = split_code_value(expiry_part)
    
    schcnt_list.append(str(len(raw_schedule)))
    schid_list.append(str(i + 1))
    asset_list.append(test_asset)
    ntrc_list.append(ntrc)
    ntrv_list.append(ntrv)
    xprc_list.append(xprc)
    xprv_list.append(xprv)
    wgt_list.append(wgt)

print(f"Asset: {test_asset}")
print(f"Schedule name: {schedule_name}")
print(f"Raw schedule: {raw_schedule}")
print(f"Parsed {len(ntrc_list)} schedule entries")

# %%
# Create asset_data_nb: Dict[str, str] for flattened asset fields
flat_asset = flatten_dict(asset_data)
asset_data_nb = dict_to_numba(flat_asset)

print(f"asset_data_nb: {len(asset_data_nb)} entries")
print(f"Keys: {sorted(asset_data_nb.keys())[:10]}...")
print()

# %%
# Create schedule_data as numpy arrays with StringDType (variable-length strings)
# This is columnar format: each key maps to a vector of values

# Check if StringDType is available (numpy >= 2.0)
try:
    string_dtype = np.dtypes.StringDType()
    print(f"Using numpy StringDType: {string_dtype}")
except AttributeError:
    # Fallback to object dtype for older numpy
    string_dtype = object
    print(f"StringDType not available, using object dtype")

# Create numpy arrays with variable-length strings
schedule_arrays = {
    "schcnt": np.array(schcnt_list, dtype=string_dtype),
    "schid": np.array(schid_list, dtype=string_dtype),
    "asset": np.array(asset_list, dtype=string_dtype),
    "ntrc": np.array(ntrc_list, dtype=string_dtype),
    "ntrv": np.array(ntrv_list, dtype=string_dtype),
    "xprc": np.array(xprc_list, dtype=string_dtype),
    "xprv": np.array(xprv_list, dtype=string_dtype),
    "wgt": np.array(wgt_list, dtype=string_dtype),
}

print(f"\nSchedule arrays (columnar format):")
for k, v in schedule_arrays.items():
    print(f"  {k}: {v.dtype} shape={v.shape} -> {list(v)}")

# %%
# Try to create a Numba dict with string array values
# Note: Numba's support for StringDType may be limited

# For now, use a Python dict of arrays (can be passed to non-JIT functions)
schedule_data = schedule_arrays

print("Two separate data structures:")
print(f"  1. asset_data_nb:  Numba Dict[str, str] with {len(asset_data_nb)} entries")
print(f"  2. schedule_data:  Python dict of numpy string arrays")
print()
print("Asset data sample:")
print(f"  asset_data_nb['Underlying'] = {asset_data_nb['Underlying']}")
print(f"  asset_data_nb['Options'] = {asset_data_nb['Options']}")
print()
print("Schedule data sample (columnar):")
print(f"  schedule_data['ntrc'] = {schedule_data['ntrc']}")
print(f"  schedule_data['xprc'] = {schedule_data['xprc']}")
print(f"  schedule_data['xprv'] = {schedule_data['xprv']}")

# %%
@njit
def get_asset_field(d, key, default=""):
    """JIT function to lookup asset field by dot-path key."""
    if key in d:
        return d[key]
    return default

# Query asset_data_nb (Numba dict)
print("JIT lookups on asset_data_nb:")
print(f"  Underlying:        {get_asset_field(asset_data_nb, 'Underlying')}")
print(f"  Options:           {get_asset_field(asset_data_nb, 'Options')}")
print(f"  WeightCap:         {get_asset_field(asset_data_nb, 'WeightCap')}")
print(f"  Market.Field:      {get_asset_field(asset_data_nb, 'Market.Field', 'N/A')}")
print(f"  Hedge.fut_code:    {get_asset_field(asset_data_nb, 'Hedge.fut_code', 'N/A')}")
print(f"  Missing:           {get_asset_field(asset_data_nb, 'DoesNotExist', '<missing>')}")

# %%
# Access schedule_data by index (columnar access)
print("Schedule data access by index:")
print()
for i in range(min(3, len(schedule_data['ntrc']))):
    print(f"  Schedule entry {i}:")
    print(f"    ntrc={schedule_data['ntrc'][i]}, ntrv={schedule_data['ntrv'][i]}")
    print(f"    xprc={schedule_data['xprc'][i]}, xprv={schedule_data['xprv'][i]}")
    print(f"    wgt={schedule_data['wgt'][i]}")
